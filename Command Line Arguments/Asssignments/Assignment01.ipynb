# %%
# Accept two numbers as command line arguments and display their sum.

import sys

# Simulate command line arguments
sys.argv = ["Assignment01.py", "10", "20"]

num1 = int(sys.argv[1])
num2 = int(sys.argv[2])

print("Sum =", num1 + num2)
# Out:
# Sum = 30
