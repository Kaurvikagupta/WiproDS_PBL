# %%
# Accept a welcome message through command line arguments.

import sys

sys.argv = ["Assignment02.py", "Welcome"]

print("File Name:", sys.argv[0])
print("Welcome Message:", sys.argv[1])
# Out:
# File Name: Assignment02.py
# Welcome Message: Welcome
