# %%
file_name = input("Enter file name: ")

with open(file_name, "r") as file:
    words = file.read().split()

longest_word = max(words, key=len)

print("Longest word:", longest_word)
# Out:
# Enter file name:  sample.txt
# Longest word: important.File
