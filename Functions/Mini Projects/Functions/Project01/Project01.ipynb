# %%
# Write a Python function that accepts a hyphen-separated sequence of colors
# and returns the colors in alphabetical order.

def sort_colors(colors):
    color_list = colors.split("-")
    color_list.sort()
    return "-".join(color_list)

colors = input("Enter hyphen-separated colors: ")

print("Sorted Colors:", sort_colors(colors))
# Out:
# Enter hyphen-separated colors:   green-red-yellow-black-white
# Sorted Colors:  green-black-red-white-yellow
