# %%
# Insert a new item before the second element in an existing list.

numbers = [10, 20, 30, 40]

numbers.insert(1, 15)

print("Updated List:", numbers)
# Out:
# Updated List: [10, 15, 20, 30, 40]
