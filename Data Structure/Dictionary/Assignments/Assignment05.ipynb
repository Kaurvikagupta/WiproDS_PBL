# %%
# Prepare a dictionary where keys are numbers between 1 and 15 and values are squares.

dictionary = {}

for i in range(1, 16):
    dictionary[i] = i * i

print(dictionary)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}
