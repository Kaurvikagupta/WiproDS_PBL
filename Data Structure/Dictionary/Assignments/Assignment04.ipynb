# %%
# Iterate over a dictionary and print keys, values and key-value pairs.

dictionary = {1: "Apple", 2: "Banana", 3: "Mango"}

print("Keys:")
for key in dictionary.keys():
    print(key)

print("\nValues:")
for value in dictionary.values():
    print(value)

print("\nKey-Value Pairs:")
for key, value in dictionary.items():
    print(key, ":", value)
# Out:
# Keys:
# 1
# 2
# 3
#
# Values:
# Apple
# Banana
# Mango
#
# Key-Value Pairs:
# 1 : Apple
# 2 : Banana
# 3 : Mango
